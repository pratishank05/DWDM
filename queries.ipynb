# %%
#libraries that we need to use 
from sqlalchemy import create_engine
import pgspecial
#load sql
# %load_ext sql
#we get access to the dabatabase 
# %sql postgresql://postgres:arnold@localhost/partsunlimited

# %% [markdown]
# ## Q1: What is the distribution of EV charging stations and EV cars across different geographic regions, and how does this relate to the popularity of EVs in those regions?

# %% [markdown]
# My EV population data is from Washington state website. If we had more data this query would of give us which regeions are leading electronic vehichles and in charging stations. This information can be very usefull for future investment.

# %%
# %%sql
# SELECT l.region, SUM(ef.vehicle_pop_quantity) AS vehicle_pop_sum, SUM(ef.ev_cs_quantity) AS total_ev_charging_stations
# FROM ev_charginging_facts ef
# JOIN ev_car_populaion ep ON ef.ev_car_pop_id = ep.ev_car_pop_id
# JOIN ev_charging_stations ecs ON ef.ev_cs_dim_id = ecs.ev_cs_dim_id
# JOIN location_dim l ON ef.location_id = l.location_id
# group by l.region;
# Out:
#  * postgresql://postgres:***@localhost/partsunlimited
# 5 rows affected.
# [('Midwest', Decimal('23'), Decimal('5978')),
#  ('Northeast', Decimal('24'), Decimal('7908')),
#  ('South', Decimal('125'), Decimal('11894')),
#  ('West', Decimal('121769'), Decimal('20966')),
#  (None, Decimal('5'), Decimal('283'))]

# %% [markdown]
# ## Q2: How has the popularity of different EV models and electric vehicle types varied by geographic region over time, and how can Parts Unlimited use this information to target their marketing and sales efforts more effectively?

# %% [markdown]
# In here we can focus on years in between 2020 and 2022, we can use rollup to show totals of each year and display the totals at the end

# %%
# %%sql
# SELECT l.region, d.year, ep.vehicle_model,
# SUM(ef.vehicle_pop_quantity) AS vehicle_pop_sum,
# SUM(ef.ev_cs_quantity) AS ev_cs_sum
# FROM ev_charginging_facts ef
# JOIN ev_car_populaion ep ON ef.ev_car_pop_id = ep.ev_car_pop_id
# JOIN ev_charging_stations ecs ON ef.ev_cs_dim_id = ecs.ev_cs_dim_id
# JOIN location_dim l ON ef.location_id = l.location_id
# JOIN date_dim d ON ef.date_id = d.date_id
# WHERE d.year BETWEEN 2020 AND 2022
# GROUP BY ROLLUP(l.region, d.year,ep.vehicle_model);
# Out:
#  * postgresql://postgres:***@localhost/partsunlimited
# 221 rows affected.
# [(None, None, None, Decimal('57167'), Decimal('26378')),
#  ('West', 2021, 'BENTAYGA', Decimal('1'), Decimal('0')),
#  ('South', 2022, 'RAV4 PRIME', Decimal('5'), Decimal('0')),
#  ('South', 2022, 'I4', Decimal('1'), Decimal('0')),
#  ('West', 2022, 'X5', Decimal('576'), Decimal('0')),
#  ('West', 2020, 'SOUL EV', Decimal('1'), Decimal('0')),
#  ('West', 2022, 'PRIUS PRIME', Decimal('157'), Decimal('0')),
#  ('West', 2021, 'AVIATOR', Decimal('37'), Decimal('0')),
#  ('West', 2022, 'CAYENNE', Decimal('31'), Decimal('0')),
#  ('West', 2020, '530E', Decimal('3'), Decimal('0')),
#  ('West', 2021, 'MODEL Y', Decimal('6616'), Decimal('0')),
#  ('West', 2021, 'X5', Decimal('299'), Decimal('0')),
#  ('Midwest', 2021, 'MODEL 3', Decimal('1'), Decimal('0')),
#  ('West', 2021, 'NIRO', Decimal('75'), Decimal('0')),
#  ('West', 2021, 'ESCAPE', Decimal('55'), Decimal('0')),
#  ('West', 2022, 'MUSTANG MACH-E', Decimal('1083'), Decimal('0')),
#  ('South', 2022, 'WRANGLER', Decimal('1'), Decimal('0')),
#  ('West', 2020, 'GLC-CLASS', Decimal('32'), Decimal('0')),
#  ('South', 2021, None, Decimal('0'), Decimal('3237')),
#  ('West', 2020, '745E', Decimal('7'), Decimal('0')),
#  ('West', 2021, '530E', Decimal('20'), Decimal('0')),
#  ('West', 2021, 'PACIFICA', Decimal('507'), Decimal('0')),
#  ('West', 2022, '330E', Decimal('56'), Decimal('0')),
#  ('West', 2020, 'IONIQ', Decimal('52'), Decimal('0')),
#  ('South', 2020, 'MODEL Y', Decimal('1'), Decimal('0')),
#  ('West', 2022, 'E-TRON', Decimal('221'), Decimal('0')),
#  ('West', 2020, 'I-PACE', Decimal('73'), Decimal('0')),
#  ('West', 2020, 'RANGE ROVER SPORT', Decimal('20'), Decimal('0')),
#  ('Northeast', 2021, None, Decimal('0'), Decimal('2484')),
#  ('Northeast', 2021, 'MODEL 3', Decimal('2'), Decimal('0')),
#  ('West', 2021, 'TAYCAN', Decimal('141'), Decimal('0')),
#  ('Northeast', 2021, 'WRANGLER', Decimal('1'), Decimal('0')),
#  ('West', 2022, 'AVIATOR', Decimal('46'), Decimal('0')),
#  ('South', 2020, None, Decimal('0'), Decimal('2199')),
#  ('West', 2022, 'MODEL X', Decimal('891'), Decimal('0')),
#  ('West', 2021, 'PRIUS PRIME', Decimal('215'), Decimal('0')),
#  ('West', 2022, 'XC90', Decimal('220'), Decimal('0')),
#  (None, 2020, None, Decimal('0'), Decimal('41')),
#  ('South', 2022, '330E', Decimal('1'), Decimal('0')),
#  ('West', 2020, 'A8 E', Decimal('3'), Decimal('0')),
#  ('West', 2021, 'Q5 E', Decimal('282'), Decimal('0')),
#  ('West', 2022, 'MODEL S', Decimal('715'), Decimal('0')),
#  ('West', 2021, 'CLARITY', Decimal('16'), Decimal('0')),
#  ('West', 2020, 'E-TRON SPORTBACK', Decimal('25'), Decimal('0')),
#  ('West', 2022, 'COUNTRYMAN', Decimal('19'), Decimal('0')),
#  ('Northeast', 2020, 'MODEL 3', Decimal('1'), Decimal('0')),
#  ('West', 2022, 'ID.4', Decimal('660'), Decimal('0')),
#  ('West', 2020, 'XC90', Decimal('59'), Decimal('0')),
#  ('West', 2020, 'I8', Decimal('1'), Decimal('0')),
#  ('South', 2022, 'BOLT EV', Decimal('1'), Decimal('0')),
#  ('West', 2020, 'S90', Decimal('3'), Decimal('0')),
#  ('West', 2022, 'C40', Decimal('126'), Decimal('0')),
#  ('West', 2022, 'TUCSON', Decimal('39'), Decimal('0')),
#  ('West', 2021, 'LEAF', Decimal('533'), Decimal('0')),
#  ('South', 2021, 'MUSTANG MACH-E', Decimal('2'), Decimal('0')),
#  ('West', 2022, 'CORSAIR', Decimal('61'), Decimal('0')),
#  ('West', 2022, 'E-TRON SPORTBACK', Decimal('74'), Decimal('0')),
#  ('West', 2020, 'MODEL X', Decimal('638'), Decimal('0')),
#  ('West', 2022, 'WRANGLER', Decimal('489'), Decimal('0')),
#  ('West', 2022, 'F-150', Decimal('279'), Decimal('0')),
#  ('Midwest', 2021, 'E-TRON', Decimal('1'), Decimal('0')),
#  ('West', 2022, 'I4', Decimal('117'), Decimal('0')),
#  ('West', 2020, 'PRIUS PRIME', Decimal('318'), Decimal('0')),
#  ('West', 2021, 'CORSAIR', Decimal('3'), Decimal('0')),
#  ('West', 2022, 'S60', Decimal('36'), Decimal('0')),
#  (None, 2020, 'MODEL Y', Decimal('1'), Decimal('0')),
#  ('Midwest', 2022, 'F-150', Decimal('1'), Decimal('0')),
#  ('West', 2021, None, Decimal('0'), Decimal('8862')),
#  ('South', 2022, 'MODEL 3', Decimal('1'), Decimal('0')),
#  ('South', 2021, 'MODEL Y', Decimal('11'), Decimal('0')),
#  ('West', 2022, 'SORENTO', Decimal('348'), Decimal('0')),
#  ('West', 2022, 'PACIFICA', Decimal('329'), Decimal('0')),
#  (None, 2021, None, Decimal('0'), Decimal('81')),
#  ('South', 2021, 'MODEL 3', Decimal('7'), Decimal('0')),
#  ('West', 2022, 'V60', Decimal('4'), Decimal('0')),
#  ('Northeast', 2020, 'PRIUS PRIME', Decimal('1'), Decimal('0')),
#  ('Northeast', 2022, 'MODEL 3', Decimal('2'), Decimal('0')),
#  ('West', 2022, 'EQB-CLASS', Decimal('44'), Decimal('0')),
#  ('West', 2020, 'I3', Decimal('54'), Decimal('0')),
#  ('West', 2022, 'PANAMERA', Decimal('6'), Decimal('0')),
#  ('Northeast', 2022, 'MODEL Y', Decimal('2'), Decimal('0')),
#  ('West', 2021, 'HARDTOP', Decimal('132'), Decimal('0')),
#  ('South', 2022, 'XC90', Decimal('1'), Decimal('0')),
#  ('Midwest', 2021, 'NIRO', Decimal('1'), Decimal('0')),
#  ('West', 2022, 'SANTA FE', Decimal('68'), Decimal('0')),
#  ('West', 2020, 'AVIATOR', Decimal('29'), Decimal('0')),
#  ('South', 2022, 'S60', Decimal('1'), Decimal('0')),
#  ('West', 2021, 'RAV4 PRIME', Decimal('748'), Decimal('0')),
#  ('West', 2022, 'FLYING SPUR', Decimal('1'), Decimal('0')),
#  ('West', 2022, 'XC40', Decimal('237'), Decimal('0')),
#  ('West', 2021, 'PANAMERA', Decimal('5'), Decimal('0')),
#  (None, 2022, 'MODEL Y', Decimal('1'), Decimal('0')),
#  ('West', 2020, 'PACIFICA', Decimal('281'), Decimal('0')),
#  ('West', 2021, 'XC40', Decimal('247'), Decimal('0')),
#  ('West', 2022, 'R1T', Decimal('864'), Decimal('0')),
#  ('West', 2020, 'KONA', Decimal('154'), Decimal('0')),
#  ('South', 2021, 'PACIFICA', Decimal('1'), Decimal('0')),
#  ('South', 2022, 'MODEL X', Decimal('1'), Decimal('0')),
#  ('West', 2022, 'E-TRON GT', Decimal('79'), Decimal('0')),
#  ('West', 2022, 'Q5', Decimal('143'), Decimal('0')),
#  ('West', 2022, 'RAV4 PRIME', Decimal('348'), Decimal('0')),
#  ('West', 2021, 'A7', Decimal('10'), Decimal('0')),
#  ('West', 2020, 'OUTLANDER', Decimal('95'), Decimal('0')),
#  ('South', 2021, 'RAV4 PRIME', Decimal('1'), Decimal('0')),
#  ('West', 2020, 'OPTIMA', Decimal('12'), Decimal('0')),
#  ('South', 2020, 'MODEL S', Decimal('1'), Decimal('0')),
#  ('West', 2021, 'KONA ELECTRIC', Decimal('158'), Decimal('0')),
#  ('Midwest', 2021, 'MODEL Y', Decimal('3'), Decimal('0')),
#  ('West', 2020, 'MODEL Y', Decimal('2363'), Decimal('0')),
#  ('West', 2022, 'BOLT EV', Decimal('930'), Decimal('0')),
#  ('South', 2022, 'X5', Decimal('1'), Decimal('0')),
#  ('West', 2020, 'NIRO', Decimal('509'), Decimal('0')),
#  ('West', 2021, 'OUTLANDER', Decimal('9'), Decimal('0')),
#  ('West', 2020, 'MODEL 3', Decimal('3583'), Decimal('0')),
#  (None, 2020, 'MODEL 3', Decimal('1'), Decimal('0')),
#  ('West', 2022, 'HARDTOP', Decimal('190'), Decimal('0')),
#  ('Midwest', 2022, 'LEAF', Decimal('1'), Decimal('0')),
#  ('West', 2022, '530E', Decimal('25'), Decimal('0')),
#  ('West', 2020, 'BOLT EV', Decimal('955'), Decimal('0')),
#  ('West', 2020, 'X3', Decimal('78'), Decimal('0')),
#  ('West', 2020, 'FUSION', Decimal('64'), Decimal('0')),
#  ('West', 2022, 'OUTLANDER', Decimal('87'), Decimal('0')),
#  ('West', 2022, 'RS E-TRON GT', Decimal('17'), Decimal('0')),
#  ('West', 2022, 'IONIQ', Decimal('10'), Decimal('0')),
#  ('South', 2022, 'KONA ELECTRIC', Decimal('1'), Decimal('0')),
#  ('West', 2021, 'MUSTANG MACH-E', Decimal('828'), Decimal('0')),
#  ('West', 2022, '745LE', Decimal('2'), Decimal('0')),
#  ('West', 2021, 'RANGE ROVER', Decimal('3'), Decimal('0')),
#  ('West', 2021, 'V60', Decimal('5'), Decimal('0')),
#  ('West', 2021, 'MODEL S', Decimal('465'), Decimal('0')),
#  ('West', 2022, 'ESCAPE', Decimal('221'), Decimal('0')),
#  ('South', 2020, 'GLC-CLASS', Decimal('1'), Decimal('0')),
#  ('West', 2022, 'XC60', Decimal('235'), Decimal('0')),
#  ('West', 2022, 'GRAND CHEROKEE', Decimal('181'), Decimal('0')),
#  ('Midwest', 2021, None, Decimal('0'), Decimal('1829')),
#  ('West', 2022, 'EDV', Decimal('220'), Decimal('0')),
#  ('West', 2021, 'WRANGLER', Decimal('626'), Decimal('0')),
#  ('South', 2022, 'MODEL Y', Decimal('9'), Decimal('0')),
#  ('West', 2020, 'XC60', Decimal('83'), Decimal('0')),
#  ('Northeast', 2021, 'RAV4 PRIME', Decimal('1'), Decimal('0')),
#  ('West', 2022, 'IX', Decimal('138'), Decimal('0')),
#  ('West', 2021, 'ID.4', Decimal('982'), Decimal('0')),
#  ('West', 2022, 'IONIQ 5', Decimal('397'), Decimal('0')),
#  ('South', 2020, 'PACIFICA', Decimal('2'), Decimal('0')),
#  ('West', 2021, 'RANGE ROVER SPORT', Decimal('5'), Decimal('0')),
#  ('West', 2022, 'EV6', Decimal('1046'), Decimal('0')),
#  ('West', 2021, 'X3', Decimal('212'), Decimal('0')),
#  ('West', 2022, 'R1S', Decimal('134'), Decimal('0')),
#  ('West', 2021, 'MODEL 3', Decimal('3832'), Decimal('0')),
#  ('South', 2020, 'BOLT EV', Decimal('1'), Decimal('0')),
#  ('West', 2020, 'BENTAYGA', Decimal('1'), Decimal('0')),
#  ('West', 2022, 'MODEL 3', Decimal('5058'), Decimal('0')),
#  ('West', 2022, 'PS2', Decimal('374'), Decimal('0')),
#  ('West', 2022, 'TRANSIT', Decimal('122'), Decimal('0')),
#  ('Midwest', 2020, None, Decimal('0'), Decimal('811')),
#  ('West', 2020, None, Decimal('0'), Decimal('5067')),
#  ('West', 2020, 'PANAMERA', Decimal('8'), Decimal('0')),
#  ('South', 2022, 'NIRO', Decimal('1'), Decimal('0')),
#  ('West', 2020, 'CAYENNE', Decimal('26'), Decimal('0')),
#  ('Northeast', 2021, 'MODEL Y', Decimal('1'), Decimal('0')),
#  ('South', 2022, 'F-150', Decimal('1'), Decimal('0')),
#  ('West', 2020, 'S60', Decimal('8'), Decimal('0')),
#  ('West', 2020, 'TAYCAN', Decimal('120'), Decimal('0')),
#  ('West', 2021, 'CAYENNE', Decimal('24'), Decimal('0')),
#  ('West', 2022, 'EQS-CLASS SEDAN', Decimal('97'), Decimal('0')),
#  ('West', 2021, '330E', Decimal('60'), Decimal('0')),
#  ('West', 2021, 'I3', Decimal('42'), Decimal('0')),
#  ('West', 2021, 'I-PACE', Decimal('6'), Decimal('0')),
#  ('West', 2021, 'E-TRON', Decimal('177'), Decimal('0')),
#  ('South', 2020, 'NIRO', Decimal('1'), Decimal('0')),
#  ('West', 2020, 'MODEL S', Decimal('384'), Decimal('0')),
#  ('West', 2021, 'BOLT EV', Decimal('381'), Decimal('0')),
#  ('West', 2022, 'LUCID AIR', Decimal('95'), Decimal('0')),
#  ('West', 2022, 'Q4', Decimal('78'), Decimal('0')),
#  ('West', 2021, 'COUNTRYMAN', Decimal('12'), Decimal('0')),
#  ('South', 2021, '330E', Decimal('1'), Decimal('0')),
#  ('Northeast', 2020, None, Decimal('0'), Decimal('1767')),
#  ('South', 2021, 'ID.4', Decimal('2'), Decimal('0')),
#  ('West', 2022, 'NX', Decimal('40'), Decimal('0')),
#  ('South', 2020, 'MODEL 3', Decimal('4'), Decimal('0')),
#  ('West', 2022, 'I-PACE', Decimal('19'), Decimal('0')),
#  ('West', 2021, 'MODEL X', Decimal('164'), Decimal('0')),
#  ('Midwest', 2020, 'MODEL Y', Decimal('2'), Decimal('0')),
#  ('West', 2021, 'XC90', Decimal('150'), Decimal('0')),
#  ('West', 2022, 'LEAF', Decimal('945'), Decimal('0')),
#  ('West', 2020, 'LEAF', Decimal('589'), Decimal('0')),
#  ('West', 2021, 'E-TRON SPORTBACK', Decimal('76'), Decimal('0')),
#  ('West', 2020, 'RANGE ROVER', Decimal('10'), Decimal('0')),
#  ('West', 2021, 'IONIQ', Decimal('26'), Decimal('0')),
#  ('West', 2021, 'S60', Decimal('27'), Decimal('0')),
#  ('West', 2020, 'CLARITY', Decimal('79'), Decimal('0')),
#  ('West', 2020, 'COUNTRYMAN', Decimal('3'), Decimal('0')),
#  ('Midwest', 2020, 'MODEL 3', Decimal('3'), Decimal('0')),
#  ('West', 2022, 'MODEL Y', Decimal('7645'), Decimal('0')),
#  ('West', 2021, 'XC60', Decimal('145'), Decimal('0')),
#  ('West', 2022, 'TAYCAN', Decimal('177'), Decimal('0')),
#  ('West', 2020, 'Q5 E', Decimal('196'), Decimal('0')),
#  ('West', 2021, 'PS2', Decimal('98'), Decimal('0')),
#  ('West', 2022, 'NIRO', Decimal('732'), Decimal('0')),
#  ('West', 2020, 'V60', Decimal('3'), Decimal('0')),
#  ('West', 2022, 'KONA ELECTRIC', Decimal('119'), Decimal('0')),
#  ('Northeast', 2021, None, Decimal('5'), Decimal('2484')),
#  (None, 2022, None, Decimal('1'), Decimal('0')),
#  ('West', 2022, None, Decimal('27701'), Decimal('0')),
#  ('Midwest', 2022, None, Decimal('2'), Decimal('0')),
#  ('West', 2020, None, Decimal('10922'), Decimal('5067')),
#  (None, 2020, None, Decimal('2'), Decimal('41')),
#  ('Midwest', 2021, None, Decimal('6'), Decimal('1829')),
#  ('South', 2021, None, Decimal('25'), Decimal('3237')),
#  ('Midwest', 2020, None, Decimal('5'), Decimal('811')),
#  ('West', 2021, None, Decimal('18455'), Decimal('8862')),
#  ('Northeast', 2022, None, Decimal('4'), Decimal('0')),
#  ('South', 2022, None, Decimal('26'), Decimal('0')),
#  ('South', 2020, None, Decimal('11'), Decimal('2199')),
#  ('Northeast', 2020, None, Decimal('2'), Decimal('1767')),
#  (None, 2021, None, Decimal('0'), Decimal('81')),
#  (None, None, None, Decimal('3'), Decimal('122')),
#  ('South', None, None, Decimal('62'), Decimal('5436')),
#  ('West', None, None, Decimal('57078'), Decimal('13929')),
#  ('Midwest', None, None, Decimal('13'), Decimal('2640')),
#  ('Northeast', None, None, Decimal('11'), Decimal('4251'))]

# %% [markdown]
# ## Q3: How does the weight of EV parts relate to their price, and how does this relationship differ across different manufacturers ?

# %% [markdown]
# * The GROUP BY clause ensures that the calculations are done for each combination,
# and the ORDER BY clause sorts the results by manufacturer name and product category for easy viewing.
# * The STDDEV_POP function calculates the population standard deviation, and dividing it by the average price gives us the coefficient of variation. The GROUP BY clause groups the results by manufacturer and product category, so we get the averages and coefficient of variation for each combination.
# * The ::numeric casts the average values to the numeric data type before rounding.
# * The second argument of the ROUND() function specifies the number of decimal places to round to.

# %%
# %%sql
# SELECT m.manufacturer_name, p.product_category,
#        ROUND(AVG(mf.weight)::numeric, 2) AS average_weight,
#        ROUND(AVG(mf.price)::numeric, 2) AS average_price,
#        ROUND(CORR(mf.weight, mf.price)::numeric, 2) AS correlation_coef
# FROM manufacturer_fact mf
# JOIN manufacturers m ON mf.manufacture_id = m.manufacture_id
# JOIN products p ON mf.product_id = p.product_id
# GROUP BY m.manufacturer_name, p.product_category
# ORDER BY m.manufacturer_name, p.product_category;
# Out:
#  * postgresql://postgres:***@localhost/partsunlimited
# 52 rows affected.
# [('AEM', 'Instrumentation', Decimal('3.00'), Decimal('1194.00'), None),
#  ('AEM', 'Miscellaneous', Decimal('4.00'), Decimal('1598.00'), None),
#  ('AM Racing', 'Motors', Decimal('165.00'), Decimal('14694.00'), Decimal('1.00')),
#  ('Behr', 'Used_Components', Decimal('3.00'), Decimal('99.00'), None),
#  ('Canadian EV', 'Miscellaneous', Decimal('4.00'), Decimal('549.00'), Decimal('1.00')),
#  ('Canadian EV', 'Motor_Adapters', Decimal('9.00'), Decimal('1300.00'), None),
#  ('Chennic', 'Charging_Accessories', Decimal('1.00'), Decimal('89.00'), None),
#  ('Curtis', 'Controller_Accessories', Decimal('2.50'), Decimal('649.00'), Decimal('1.00')),
#  ('Curtis', 'Controllers', Decimal('16.33'), Decimal('1787.67'), Decimal('0.71')),
#  ('Deltec', 'Instrumentation', Decimal('2.33'), Decimal('50.67'), Decimal('0.95')),
#  ('DilithiumBMS', 'Charging_Accessories', Decimal('1.00'), Decimal('370.00'), None),
#  ('Elcon', 'Chargers', Decimal('17.00'), Decimal('884.00'), Decimal('1.00')),
#  ('Elcon', 'DC_Converters', Decimal('6.00'), Decimal('549.00'), None),
#  ('EmproShunts', 'Used_Components', Decimal('0.00'), Decimal('20.00'), None),
#  ('EV West', 'Batteries', Decimal('10.00'), Decimal('648.50'), Decimal('-1.00')),
#  ('EV West', 'BatteryEnclosuresAcc', Decimal('13.67'), Decimal('672.33'), Decimal('1.00')),
#  ('EV West', 'Charging_Accessories', Decimal('2.62'), Decimal('68.81'), Decimal('0.40')),
#  ('EV West', 'Controller_Accessories', Decimal('3.75'), Decimal('98.44'), Decimal('0.73')),
#  ('EV West', 'DrivetrainComponents', Decimal('29.60'), Decimal('766.20'), Decimal('0.83')),
#  ('EV West', 'EV_Conversion_Kits', Decimal('376.67'), Decimal('16426.65'), Decimal('-0.70')),
#  ('EV West', 'Hose_Fittings', Decimal('0.10'), Decimal('4.85'), Decimal('-0.02')),
#  ('EV West', 'Instrumentation', Decimal('1.00'), Decimal('149.00'), None),
#  ('EV West', 'Miscellaneous', Decimal('1.43'), Decimal('34.73'), Decimal('0.63')),
#  ('EV West', 'Motor_Accessories', Decimal('13.71'), Decimal('684.43'), Decimal('0.95')),
#  ('EV West', 'Motor_Adapters', Decimal('125.00'), Decimal('2197.00'), Decimal('1.00')),
#  ('EV West', 'Services', Decimal('0.00'), Decimal('393.75'), None),
#  ('EV West', 'Used_Components', Decimal('2.00'), Decimal('139.00'), None),
#  ('HPEVS', 'Controller_Accessories', Decimal('3.00'), Decimal('528.50'), Decimal('1.00')),
#  ('HPEVS', 'Motors', Decimal('101.54'), Decimal('4940.23'), Decimal('0.82')),
#  ('Manzanita', 'Chargers', Decimal('17.73'), Decimal('3120.00'), Decimal('0.88')),
#  ('Manzanita', 'Controllers', Decimal('27.50'), Decimal('3600.00'), Decimal('1.00')),
#  ('Modular EV', 'Charging_Accessories', Decimal('1.00'), Decimal('45.00'), None),
#  ('MSD Ignition', 'Miscellaneous', Decimal('1.00'), Decimal('19.99'), None),
#  ('NetGainMotors', 'Controllers', Decimal('11.00'), Decimal('2050.00'), None),
#  ('NetGainMotors', 'Motors', Decimal('120.00'), Decimal('5275.00'), None),
#  ('QuickChargePower', 'Charging_Accessories', Decimal('2.00'), Decimal('389.00'), None),
#  ('RinconPower', 'BatteryEnclosuresAcc', Decimal('3.00'), Decimal('159.00'), None),
#  ('RinehartMotionSystems', 'Controllers', Decimal('22.50'), Decimal('7800.00'), Decimal('1.00')),
#  ('Samsung', 'Batteries', Decimal('63.75'), Decimal('521.75'), Decimal('0.95')),
#  ('Smart', 'Used_Components', Decimal('2.40'), Decimal('68.00'), Decimal('0.04')),
#  ('SSBC', 'Miscellaneous', Decimal('9.00'), Decimal('288.00'), None),
#  ('TBSElectronics', 'Instrumentation', Decimal('1.00'), Decimal('182.00'), None),
#  ('Tesla', 'Batteries', Decimal('48.50'), Decimal('1189.50'), Decimal('1.00')),
#  ('Tesla', 'Controllers', Decimal('3.00'), Decimal('2699.00'), None),
#  ('Tesla', 'DrivetrainComponents', Decimal('1.00'), Decimal('8.00'), None),
#  ('Tesla', 'Motors', Decimal('305.00'), Decimal('11900.00'), Decimal('1.00')),
#  ('Tesla', 'Used_Components', Decimal('27.50'), Decimal('804.50'), Decimal('1.00')),
#  ('Tyco Kilovac', 'Used_Components', Decimal('5.00'), Decimal('60.00'), None),
#  ('UnknownVendor', 'Batteries', Decimal('39.00'), Decimal('839.00'), Decimal('1.00')),
#  ('UnknownVendor', 'Instrumentation', Decimal('1.00'), Decimal('179.50'), None),
#  ('UnknownVendor', 'Miscellaneous', Decimal('4.43'), Decimal('256.00'), Decimal('0.81')),
#  ('UnknownVendor', 'Used_Components', Decimal('1.00'), Decimal('25.00'), None)]

# %% [markdown]
# The analysis reveals that the weight of EV parts is positively correlated with their prices for most manufacturers, including Tesla. For instance, batteries have a correlation coefficient of 1, indicating a strong positive correlation between weight and price. However, some manufacturers, such as EV West, exhibit a negative correlation for some products, like EV conversion kits, suggesting that as the weight of these parts increase, their prices decrease.
#
# The query provides valuable insights for the supply chain department, helping them understand how the weight of EV parts affects their prices across different manufacturers. By leveraging this information, the department can make informed decisions when negotiating prices with suppliers, identifying cost-saving opportunities, and optimizing their inventory management strategies.

# %% [markdown]
# ## Q4: What is the average price, weight, and quantity of products sold by Parts Unlimited over time, and how does this vary across different geographic regions in which the products have been manufactured?

# %% [markdown]
# This shows how many different types products has been released in 2020

# %%
# %%sql
# SELECT SUM(mf2.quantity)::numeric
#               FROM manufacturer_fact mf2
#               JOIN date_dim d2 ON mf2.date_id = d2.date_id
#                  WHERE d2.year = 2020
# Out:
#  * postgresql://postgres:***@localhost/partsunlimited
# 1 rows affected.
# [(Decimal('109'),)]

# %% [markdown]
# In here we can see over all summary also showing the what percentage of the product has been provided by the manufacturer

# %%
# %%sql
# SELECT l.region, l.city, l.country, m.manufacturer_name, d.year,
#        ROUND(AVG(mf.weight)::numeric, 2) AS average_weight,
#        ROUND(AVG(mf.price)::numeric, 2) AS average_price,
#        SUM(mf.quantity)::numeric AS total_distinct_product,
#        ROUND(SUM(mf.quantity)::numeric /
#              (SELECT SUM(mf2.quantity)::numeric
#               FROM manufacturer_fact mf2
#               JOIN date_dim d2 ON mf2.date_id = d2.date_id
#               WHERE d2.year = d.year)::numeric * 100, 2) AS percent_of_products_provided
# FROM manufacturer_fact mf
# JOIN manufacturers m ON mf.manufacture_id = m.manufacture_id
# JOIN products p ON mf.product_id = p.product_id
# JOIN location_dim l ON mf.location_id = l.location_id
# JOIN date_dim d ON mf.date_id = d.date_id
# GROUP BY l.region, l.city, l.country, m.manufacturer_name, d.year
# ORDER BY l.region, l.city, l.country, m.manufacturer_name, d.year;
# Out:
#  * postgresql://postgres:***@localhost/partsunlimited
# 26 rows affected.
# [('Midwest', 'Batavia', 'US', 'Deltec', 2022, Decimal('2.33'), Decimal('50.67'), Decimal('3'), Decimal('10.00')),
#  ('Midwest', 'Georgetown', 'US', 'NetGainMotors', 2021, Decimal('83.67'), Decimal('4200.00'), Decimal('3'), Decimal('23.08')),
#  ('Midwest', 'Indianapolis', 'US', 'EmproShunts', 2019, Decimal('0.00'), Decimal('20.00'), Decimal('1'), Decimal('4.17')),
#  ('Northeast', 'Clarence', 'US', 'SSBC', 2019, Decimal('9.00'), Decimal('288.00'), Decimal('1'), Decimal('4.17')),
#  ('Northeast', 'Mount Kisco', 'US', 'Curtis', 2020, Decimal('10.80'), Decimal('1332.20'), Decimal('5'), Decimal('4.59')),
#  ('South', 'Cedar Park', 'US', 'AM Racing', 2019, Decimal('165.00'), Decimal('14694.00'), Decimal('2'), Decimal('8.33')),
#  ('South', 'El Paso', 'US', 'MSD Ignition', 2021, Decimal('1.00'), Decimal('19.99'), Decimal('1'), Decimal('7.69')),
#  ('South', 'Pryor', 'US', 'Modular EV', 2019, Decimal('1.00'), Decimal('45.00'), Decimal('1'), Decimal('4.17')),
#  ('South', 'Round Rock', 'US', 'HPEVS', 2020, Decimal('88.40'), Decimal('4352.00'), Decimal('15'), Decimal('13.76')),
#  ('Unknown', 'Delta', 'Canada', 'Canadian EV', 2022, Decimal('8.58'), Decimal('1237.42'), Decimal('24'), Decimal('80.00')),
#  ('Unknown', 'Lod', 'Israel', 'Elcon', 2020, Decimal('10.40'), Decimal('683.00'), Decimal('5'), Decimal('4.59')),
#  ('Unknown', 'Mississauga', 'Canada', 'TBSElectronics', 2022, Decimal('1.00'), Decimal('182.00'), Decimal('2'), Decimal('6.67')),
#  ('Unknown', 'Richmond Hill', 'Canada', 'Manzanita', 2020, Decimal('21.64'), Decimal('3312.00'), Decimal('5'), Decimal('4.59')),
#  ('Unknown', 'Seoul', 'South Korea', 'Samsung', 2019, Decimal('63.75'), Decimal('521.75'), Decimal('4'), Decimal('16.67')),
#  ('Unknown', 'Shenzhen', 'China', 'Chennic', 2020, Decimal('1.00'), Decimal('89.00'), Decimal('1'), Decimal('0.92')),
#  ('Unknown', 'Stuttgart', 'Germany', 'Behr', 2019, Decimal('3.00'), Decimal('99.00'), Decimal('1'), Decimal('4.17')),
#  ('Unknown', 'Stuttgart', 'Germany', 'Smart', 2021, Decimal('2.40'), Decimal('68.00'), Decimal('5'), Decimal('38.46')),
#  ('Unknown', 'Unknown', 'Unknown', 'UnknownVendor', 2019, Decimal('9.33'), Decimal('321.17'), Decimal('12'), Decimal('50.00')),
#  ('Unknown', 'Victoria', 'Canada', 'QuickChargePower', 2021, Decimal('2.00'), Decimal('389.00'), Decimal('1'), Decimal('7.69')),
#  ('West', 'Hawthorne', 'US', 'AEM', 2020, Decimal('3.33'), Decimal('1328.67'), Decimal('3'), Decimal('2.75')),
#  ('West', 'Menlo Park', 'US', 'Tyco Kilovac', 2022, Decimal('5.00'), Decimal('60.00'), Decimal('1'), Decimal('3.33')),
#  ('West', 'Oceanside', 'US', 'DilithiumBMS', 2021, Decimal('1.00'), Decimal('370.00'), Decimal('2'), Decimal('15.38')),
#  ('West', 'Oceanside', 'US', 'RinconPower', 2021, Decimal('3.00'), Decimal('159.00'), Decimal('1'), Decimal('7.69')),
#  ('West', 'Palo Alto', 'US', 'Tesla', 2018, Decimal('152.82'), Decimal('6017.73'), Decimal('11'), Decimal('100.00')),
#  ('West', 'San Marcos', 'US', 'EV West', 2020, Decimal('68.69'), Decimal('2896.52'), Decimal('75'), Decimal('68.81')),
#  ('West', 'Wilsonville', 'US', 'RinehartMotionSystems', 2019, Decimal('22.50'), Decimal('7800.00'), Decimal('2'), Decimal('8.33'))]

# %% [markdown]
# we can breakdown a year to see a better picture, For 2020 the biggiest wendor is EV West and follows by HPEVS

# %%
# %%sql
# SELECT l.region, l.city, l.country, m.manufacturer_name, d.year,
#        ROUND(AVG(mf.weight)::numeric, 2) AS average_weight,
#        ROUND(AVG(mf.price)::numeric, 2) AS average_price,
#        SUM(mf.quantity)::numeric AS total_distinct_product,
#        ROUND(SUM(mf.quantity)::numeric /
#              (SELECT SUM(mf2.quantity)::numeric
#               FROM manufacturer_fact mf2
#               JOIN date_dim d2 ON mf2.date_id = d2.date_id
#               WHERE d2.year = d.year)::numeric * 100, 2) AS percent_of_products_provided
# FROM manufacturer_fact mf
# JOIN manufacturers m ON mf.manufacture_id = m.manufacture_id
# JOIN products p ON mf.product_id = p.product_id
# JOIN location_dim l ON mf.location_id = l.location_id
# JOIN date_dim d ON mf.date_id = d.date_id
# WHERE d.year = 2020
# GROUP BY l.region, l.city, l.country, m.manufacturer_name, d.year
# ORDER BY l.region, l.city, l.country, m.manufacturer_name, d.year;
# Out:
#  * postgresql://postgres:***@localhost/partsunlimited
# 7 rows affected.
# [('Northeast', 'Mount Kisco', 'US', 'Curtis', 2020, Decimal('10.80'), Decimal('1332.20'), Decimal('5'), Decimal('4.59')),
#  ('South', 'Round Rock', 'US', 'HPEVS', 2020, Decimal('88.40'), Decimal('4352.00'), Decimal('15'), Decimal('13.76')),
#  ('Unknown', 'Lod', 'Israel', 'Elcon', 2020, Decimal('10.40'), Decimal('683.00'), Decimal('5'), Decimal('4.59')),
#  ('Unknown', 'Richmond Hill', 'Canada', 'Manzanita', 2020, Decimal('21.64'), Decimal('3312.00'), Decimal('5'), Decimal('4.59')),
#  ('Unknown', 'Shenzhen', 'China', 'Chennic', 2020, Decimal('1.00'), Decimal('89.00'), Decimal('1'), Decimal('0.92')),
#  ('West', 'Hawthorne', 'US', 'AEM', 2020, Decimal('3.33'), Decimal('1328.67'), Decimal('3'), Decimal('2.75')),
#  ('West', 'San Marcos', 'US', 'EV West', 2020, Decimal('68.69'), Decimal('2896.52'), Decimal('75'), Decimal('68.81'))]

# %% [markdown]
# ## Q5 : How does the demand for charging stations and the number of vendors operating in different regions relate to the size of the EV market, and what trends can be identified over time?

# %% [markdown]
# In here we can look at the sum of the population and charging stations. One thing that we notice that in west we do not see new charging stations for the last two years but for those years I see increase in the other regions.

# %%
# %%sql
# select l.region, m.year,
# sum(mfc.vehicle_pop_quantity) as number_of_cars,
# sum(mfc.ev_cs_quantity) as number_of_chargingSta,
# COUNT(DISTINCT ma.manufacture_id) AS number_of_manufacturers
# from manufacturer_fact_cumulative mfc
# JOIN manufacturers ma ON mfc.manufacture_id = ma.manufacture_id
# JOIN location_dim l ON mfc.location_id = l.location_id
# JOIN month_dim m ON mfc.month_id = m.month_id
# WHERE m.year BETWEEN 2020 AND 2023
# GROUP BY l.region, m.year;
# Out:
#  * postgresql://postgres:***@localhost/partsunlimited
# 18 rows affected.
# [('Midwest', 2020, 3, 624, 2),
#  ('Midwest', 2021, 4, 1474, 2),
#  ('Midwest', 2022, 2, 0, 2),
#  ('Northeast', 2020, 2, 1219, 1),
#  ('Northeast', 2021, 2, 1685, 1),
#  ('Northeast', 2022, 4, 0, 1),
#  ('Northeast', 2023, 0, 0, 1),
#  ('South', 2020, 10, 1697, 1),
#  ('South', 2021, 20, 2595, 1),
#  ('South', 2022, 17, 0, 2),
#  ('South', 2023, 3, 0, 1),
#  ('Unknown', 2020, 0, 0, 3),
#  ('Unknown', 2021, 0, 0, 1),
#  ('Unknown', 2023, 0, 0, 2),
#  ('West', 2020, 5490, 3140, 1),
#  ('West', 2021, 9175, 5312, 2),
#  ('West', 2022, 13817, 0, 2),
#  ('West', 2023, 5053, 0, 2)]
